# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('weather.csv')

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W           NaN  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# ## Operating on Null Values
#
# As we have seen, Pandas treats ``None`` and ``NaN`` as essentially interchangeable for indicating missing or null values.
# To facilitate this convention, there are several useful methods for detecting, removing, and replacing null values in Pandas data structures.
# They are:
#
# - ``isnull()``: Generate a boolean mask indicating missing values
# - ``notnull()``: Opposite of ``isnull()``
# - ``dropna()``: Return a filtered version of the data
# - ``fillna()``: Return a copy of the data with missing values filled or imputed
#
# We will conclude this section with a brief exploration and demonstration of these routines.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        365 non-null    float64
#  1   MaxTemp        364 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   353 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    363 non-null    float64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df[df.WindDir9am.isnull()]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 138     12.5     29.9       0.0          5.8      10.7          NW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 174      7.5     19.0       0.0          4.0       6.8         ENE
# 176      5.0     20.9       0.0          2.0       8.9         WNW
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 189     -0.2     18.1       0.0          4.4       9.4          NW
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 200     -2.7     18.1       0.0          2.2       9.3           W
# 208      4.9     18.1       5.2          1.2       8.5         NNW
# 209      1.4     16.8       0.0          1.6       8.2          NW
# ...

# %%
df['WindDir9am'][df.WindDir9am.isnull()].agg('count')
# Out:
# 0

# %%
df['WindDir9am']
# Out:
# 0       SW
# 1        E
# 2        N
# 3      WNW
# 4      SSE
#       ...
# 361    SSE
# 362    NNW
# 363    ENE
# 364    SSW
# 365     NW
# Name: WindDir9am, Length: 366, dtype: object

# %%
df[df.MinTemp.isnull()]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 9      NaN     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 9           31.0          S        ESE           7.0  ...           32
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 9       1024.1       1020.7         7         1     13.3     21.7        Yes
#
#    RISK_MM RainTomorrow
# 9      0.0           No
#
# [1 rows x 22 columns]

# %%
df.MinTemp.head(12)
# Out:
# 0      8.0
# 1     14.0
# 2     13.7
# 3     13.3
# 4      7.6
# 5      6.2
# 6      6.1
# 7      8.3
# 8      8.8
# 9      NaN
# 10     9.1
# 11     8.5
# Name: MinTemp, dtype: float64

# %%
df.MinTemp.fillna(method='ffill',inplace=True)

# %%
#df['MinTemp'].fillna(method='ffill')

# %%
df.MinTemp.head(12)
# Out:
# 0      8.0
# 1     14.0
# 2     13.7
# 3     13.3
# 4      7.6
# 5      6.2
# 6      6.1
# 7      8.3
# 8      8.8
# 9      8.8
# 10     9.1
# 11     8.5
# Name: MinTemp, dtype: float64

# %%
df[df.MaxTemp.isnull()]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6       6.1      NaN       0.2          4.2       8.4          SE
# 12     10.1      NaN       0.0          7.2      13.0         WNW
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 6            43.0         SE        ESE           NaN  ...           47
# 12           30.0          S         NW           NaN  ...           29
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 6        1024.6       1022.2         4         6     12.4     17.3         No
# 12       1022.0       1017.1         0         1     17.0     27.1         No
#
#     RISK_MM RainTomorrow
# 6       0.0           No
# 12      0.0           No
#
# [2 rows x 22 columns]

# %%
df.MaxTemp.head(14)
# Out:
# 0     24.3
# 1     26.9
# 2     23.4
# 3     15.5
# 4     16.1
# 5     16.9
# 6      NaN
# 7     17.0
# 8     19.5
# 9     22.8
# 10    25.2
# 11    27.3
# 12     NaN
# 13    30.9
# Name: MaxTemp, dtype: float64

# %%
#df.MaxTemp.fillna(method='bfill',inplace=True)

# %%
df.MaxTemp.head(14)
# Out:
# 0     24.3
# 1     26.9
# 2     23.4
# 3     15.5
# 4     16.1
# 5     16.9
# 6      NaN
# 7     17.0
# 8     19.5
# 9     22.8
# 10    25.2
# 11    27.3
# 12     NaN
# 13    30.9
# Name: MaxTemp, dtype: float64

# %%
df.MaxTemp.interpolate(method='linear',inplace=True)

# %%
df.MaxTemp.interpolate?

# %%
df.MaxTemp.head(14)
# Out:
# 0     24.30
# 1     26.90
# 2     23.40
# 3     15.50
# 4     16.10
# 5     16.90
# 6     16.95
# 7     17.00
# 8     19.50
# 9     22.80
# 10    25.20
# 11    27.30
# 12    29.10
# 13    30.90
# Name: MaxTemp, dtype: float64

# %%
df.shape
# Out:
# (366, 22)

# %%
df.dropna()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df.shape
# Out:
# (319, 22)

# %%
df.dropna(how='any',inplace=True)

# %%
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.dropna(how='any')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...
